# %%
# Import all the required files
import pureml
from pureml.decorators import load_data,transformer,dataset,model
import numpy as np
import pandas as pd
import lightgbm as lgb
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import warnings

warnings.simplefilter("ignore")
rand_seed = 1234
np.random.seed(rand_seed)

# %%
@load_data()
def load_dataset():
    df = pd.read_excel(io='default of credit card clients.xls',header  = 1)

    return df

# %%
@transformer()
def remove_columns(df):
    return df.drop(['ID'],axis =1)

# %%
@transformer()
def rename_columns(df):
    return df.rename(columns={"PAY_0": "PAY_1","default payment next month":"default"})

# %%
@transformer()
def dataset_imbalances(df):
    categorical_features = ["SEX", "EDUCATION", "MARRIAGE"]

    for col_name in categorical_features:
        df[col_name] = df[col_name].astype("category")

    Y, A_str = df.loc[:, "default"], df.loc[:, "SEX"]
    X = pd.get_dummies(df.drop(columns=["default", "SEX"]))

    #A_str = A.map({1: "male", 2: "female"})

    A_str.value_counts(normalize=True)
    Y.value_counts(normalize=True)
    
    # Generate "Interest" column as a DataFrame_str
    interest_values = np.random.normal(loc=2 * Y, scale=A_str)
    interest_column = pd.DataFrame(interest_values, columns=["Interest"])

    # Concatenate "Interest" column with X DataFrame
    X = pd.concat([X, interest_column], axis=1)

    return {'X':X,'Y':Y,'A_str':A_str}

# %%
@transformer()
def resample_training_data(X_train, Y_train, A_train):
   
    negative_ids = Y_train[Y_train == 0].index
    positive_ids = Y_train[Y_train == 1].index
    balanced_ids = positive_ids.union(
        np.random.choice(a=negative_ids, size=len(positive_ids)))

    X_train = X_train.loc[balanced_ids, :]
    Y_train = Y_train.loc[balanced_ids]
    A_train = A_train.loc[balanced_ids]
    return  {"X_train": X_train, "Y_train":Y_train, "A_train": A_train}

# %%
from pureml.decorators import dataset

@dataset(label='credit_datasetexample_final_desc:main',upload=True)
def create_dataset():
    df = load_dataset()
    df = remove_columns(df)
    df = rename_columns(df)
    data  = dataset_imbalances(df)
    X,Y,A_str = data['X'],data['Y'],data['A_str']
    X_train, X_test, y_train, y_test, A_train, A_test = train_test_split(X, Y, A_str, test_size=0.35, stratify=Y)
    data = resample_training_data(X_train, y_train, A_train)
    X_train, y_train, A_train = data['X_train'],data['Y_train'],data['A_train']
    A_test = A_test.to_numpy()
    y_test = y_test.to_numpy()
    print(A_test)
    #return {"sensitive_features" : A_test}
    return {"x_train":X_train,"y_train":y_train,"x_test":X_test,"y_test":y_test,"sensitive_features" : A_test}
    #return {"x_train":X_train,"y_train":y_train,"x_test":X_test,"y_test":y_test}


create_dataset()
# Out:
# [2 1 2 ... 2 2 2]
#  Connected to Dataset
#  Connected to Branch
# Version:  v1
# Dataset label:  credit_datasetexample_final_desc:main:v1
# Dataset and lineage have been registered!
# {'x_train':        LIMIT_BAL  AGE  PAY_1  PAY_2  PAY_3  PAY_4  PAY_5  PAY_6  BILL_AMT1  \
#  0          20000   24      2      2     -1     -1     -2     -2       3913
#  1         120000   26     -1      2      0      0      0      2       2682
#  3          50000   37      0      0      0      0      0      0      46990
#  9          20000   35     -2     -2     -2     -2     -1     -1          0
#  10        200000   34      0      0      2      0      0     -1      11073
#  ...          ...  ...    ...    ...    ...    ...    ...    ...        ...
#  29983      20000   44     -2     -2     -2     -2     -2     -2       1822
#  29991     210000   34      3      2      2      2      2      2       2500
#  29994      80000   34      2      2      2      2      2      2      72557
#  29997      30000   37      4      3      2     -1      0      0       3565
#  29999      50000   46      0      0      0      0      0      0      47929
#
#         BILL_AMT2  ...  EDUCATION_2  EDUCATION_3  EDUCATION_4  EDUCATION_5  \
#  0           3102  ...            1            0            0            0
#  1           1725  ...            1            0            0            0
#  3          48233  ...            1            0            0            0
#  9              0  ...            0            1            0            0
#  10          9787  ...            0            1            0            0
#  ...          ...  ...          ...          ...          ...          ...
#  29983       2872  ...            1            0            0            0
#  29991       2500  ...            1            0            0            0
#  29994      77708  ...            1            0            0            0
#  29997       3356  ...            1            0            0            0
#  29999      48905  ...            1            0            0            0
#
#         EDUCATION_6  MARRIAGE_0  MARRIAGE_1  MARRIAGE_2  MARRIAGE_3  Interest
#  0                0           0           1           0           0  4.972752
#  1                0           0           0           1           0  4.709630
#  3                0           0           1           0           0 -5.112737
#  9                0           0           0           1           0 -0.913915
#  10               0           0           0           1           0 -0.342010
#  ...            ...         ...         ...         ...         ...       ...
#  29983            0           0           1           0           0 -1.461448
#  29991            0           0           1           0           0  1.920590
#  29994            0           0           0           1           0  1.023366
#  29997            0           0           0           1           0  1.967795
#  29999            0           0           1           0           0  1.148732
#
#  [8626 rows x 32 columns],
#  'y_train': 0        1
#  1        1
#  3        0
#  9        0
#  10       0
#          ..
#  29983    0
#  29991    1
#  29994    1
#  29997    1
#  29999    1
#  Name: default, Length: 8626, dtype: int64,
#  'x_test':        LIMIT_BAL  AGE  PAY_1  PAY_2  PAY_3  PAY_4  PAY_5  PAY_6  BILL_AMT1  \
#  13947     200000   49      0      0      2      0      0      0     196272
#  5048       80000   30      2      2      2      0      0      2      72183
#  13303     300000   31      0      0      0      0      0      0      89240
#  7065       70000   25      0      0      0      0      0      0       8272
#  14901     260000   42     -2     -2     -2     -2     -2     -2        387
#  ...          ...  ...    ...    ...    ...    ...    ...    ...        ...
#  24517     280000   32      0      0      0      0      0      0       4524
#  17320      30000   29      0      0      2      0      0     -2      22501
#  25281     150000   26     -1     -1      0      0     -1     -1        242
#  4129      170000   52     -1     -1      2     -1     -1     -1       2939
#  15197     140000   26      0      0      0      0      0      0     182424
#
#         BILL_AMT2  ...  EDUCATION_2  EDUCATION_3  EDUCATION_4  EDUCATION_5  \
#  13947     209034  ...            0            1            0            0
#  5048       81844  ...            1            0            0            0
#  13303      92016  ...            1            0            0            0
#  7065       10128  ...            0            0            0            0
#  14901        616  ...            0            0            0            0
#  ...          ...  ...          ...          ...          ...          ...
#  24517       2625  ...            0            0            0            0
#  17320      20210  ...            1            0            0            0
#  25281       3180  ...            1            0            0            0
#  4129        5447  ...            0            0            0            0
#  15197     115115  ...            1            0            0            0
#
#         EDUCATION_6  MARRIAGE_0  MARRIAGE_1  MARRIAGE_2  MARRIAGE_3  Interest
#  13947            0           0           0           1           0  0.815071
#  5048             0           0           0           1           0  2.425785
#  13303            0           0           1           0           0 -0.558820
#  7065             0           0           0           1           0 -2.038902
#  14901            0           0           1           0           0  4.851429
#  ...            ...         ...         ...         ...         ...       ...
#  24517            0           0           0           1           0  0.768369
#  17320            0           0           0           1           0 -0.503136
#  25281            0           0           0           1           0 -0.224706
#  4129             0           0           1           0           0  0.509122
#  15197            0           0           0           1           0  4.395469
#
#  [10500 rows x 32 columns],
#  'y_test': array([0, 1, 0, ..., 0, 0, 0]),
#  'sensitive_features': array([2, 1, 2, ..., 2, 2, 2])}

# %%
data = pureml.dataset.fetch('credit_datasetexample_final_desc:main:v1')
x_test = data['x_test']
y_test = data['y_test']

# %%
a_test = data["sensitive_features"]

# %%
# print(x_test.shape,y_test.shape,a_test.shape)
print(a_test)
# Out:
# [2 1 2 ... 2 2 2]

# %%
@model(label='credit_modelexample_final_desc:main')
def create_model():
    data = pureml.dataset.fetch('credit_datasetexample_final_desc:main:v1')
    x_train = data['x_train']
    y_train = data['y_train']
    lgb_params = {
    #"objective": "binary",
    "metric": "auc",
    "learning_rate": 0.03,
    "num_leaves": 10,
    "max_depth": 3,
    "random_state": rand_seed,
    "n_jobs": 1,}

    pureml.log(params=lgb_params)
    estimator = Pipeline(
        steps=[
            ("preprocessing", StandardScaler()),
            ("classifier", lgb.LGBMClassifier(**lgb_params)),
        ]
    )

    estimator.fit(x_train, y_train)
    return estimator

create_model()
# Out:
# [LightGBM] [Info] Number of positive: 4313, number of negative: 4313
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002182 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3514
# [LightGBM] [Info] Number of data points in the train set: 8626, number of used features: 29
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# branch_exists True
# Model has been registered!
# Model Version:  v2
# Model label:  credit_modelexample_final_desc:main:v2
# No metrics are found in config
# Params have been registered!
# No figures are found in config
# Pipeline(steps=[('preprocessing', StandardScaler()),
#                 ('classifier',
#                  LGBMClassifier(learning_rate=0.03, max_depth=3, metric='auc',
#                                 n_jobs=1, num_leaves=10, random_state=1234))])

# %%
pureml.model.fetch(label='credit_modelexample_final_desc:main:v2')
# Out:
# Pipeline(steps=[('preprocessing', StandardScaler()),
#                 ('classifier',
#                  LGBMClassifier(learning_rate=0.03, max_depth=3, metric='auc',
#                                 n_jobs=1, num_leaves=10, random_state=1234))])

# %%
pureml.predict.add(label ='credit_modelexample_final_desc:main:v2',paths={'predict':'predict.py'})
# Out:
# Predict Function has been registered!
# {"status":200,"data":[{"key":"predict","data":"https://pub-cc8d623e43954c8fa75380adfd3bb762.r2.dev/model-registry/b
# c0b992f-33f3-4b9a-8836-c231bd289924/models/2d680b4c-b646-4e11-9f65-064bb5df7ed8/1712ce02-1a69-46ed-9ffe-d477a07cc77
# 7/logs/predict_lxkKzgOM4p.txt","model_version":{"uuid":"21ab3347-26bb-413d-a4d5-34154e06085e","version":"v2"},"data
# set_version":{"uuid":"00000000-0000-0000-0000-000000000000","version":""}}],"message":"Logs created"}

# %%
pureml.predict.fetch(label='credit_modelexample_final_desc:main:v2')
# Out:
#  predict file predict.py has been fetched

# %%
import pureml
pureml.eval(task_type=['classification','fairness'],label_model='credit_modelexample_final_desc:main:v2',label_dataset='credit_datasetexample_final_desc:main:v1')
# Out:
#  Succesfully fetched the dataset
#  Succesfully fetched the predictor
#  Succesfully fetched the model
# Dataset Keys: dict_keys(['x_train', 'y_train', 'x_test', 'y_test', 'sensitive_features'])
# Data in sensitive_features: [2 1 2 ... 2 2 2]
# /mnt/sda1/Pureml-Files/Examples/Credit_Example_for_demo/credit_example/testing_desc1/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1969: UndefinedMetricWarning: 'k' (2) greater than or equal to 'n_classes' (2) will result in a perfect score and is therefore meaningless.
#   warnings.warn(
# /mnt/sda1/Pureml-Files/Examples/Credit_Example_for_demo/credit_example/testing_desc1/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1969: UndefinedMetricWarning: 'k' (2) greater than or equal to 'n_classes' (2) will result in a perfect score and is therefore meaningless.
#   warnings.warn(
# /mnt/sda1/Pureml-Files/Examples/Credit_Example_for_demo/credit_example/testing_desc1/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1969: UndefinedMetricWarning: 'k' (2) greater than or equal to 'n_classes' (2) will result in a perfect score and is therefore meaningless.
#   warnings.warn(
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# {
#     'status': 200,
#     'data': [
#         {
#             'uuid': '00000000-0000-0000-0000-000000000000',
#             'risk': 'Recall',
#             'value': '0.80',
#             'severity': 'pass',
#             'summary': 'recall has a value of 0.8 with moderate as Severity Index against the 0.8 as threshold ',
#             'description': 'This test checks the Recall metric to see both if its performance on the evaluation set
# alone is satisfactory, as well as if performance in terms of Recall has degraded from the reference to evaluation
# set. The key detail displays whether the given performance metric has degraded beyond a defined threshold.',
#             'matters': 'During production, factors like distribution shift or a change in <span>p(y|x)</span> may
# cause model performance to decrease significantly.',
#             'threshold': '0.8',
#             'category': 'performance',
#             'created_at': '2023-08-10T09:43:45.136856Z'
#         },
#         {
#             'uuid': '00000000-0000-0000-0000-000000000000',
#             'risk': 'F1',
#             'value': '0.62',
#             'severity': 'pass',
#             'summary': 'f1 has a value of 0.62 with moderate as Severity Index against the 0.6 as threshold ',
#             'description': 'This test checks the F1 metric to see both if its performance on the evaluation set
# alone is satisfactory, as well as if performance in terms of F1 has degraded from the reference to evaluation set.
# The key detail displays whether the given performance metric has degraded beyond a defined threshold.',
#             'matters': 'During production, factors like distribution shift or a change in <span>p(y|x)</span> may
# cause model performance to decrease significantly.',
#             'threshold': '0.6',
#             'category': 'performance',
#             'created_at': '2023-08-10T09:43:46.04704Z'
#         },
#         {
#             'uuid': '00000000-0000-0000-0000-000000000000',
#             'risk': 'Balanced Accuracy Score',
#             'value': '0.79',
#             'severity': 'pass',
#             'summary': 'balanced_accuracy_score has a value of 0.79 with pass as Severity Index against the 0.6 as
# threshold ',
#             'description': 'This test checks the Balanced Accuracy metric to see both if its performance on the
# evaluation set alone is satisfactory, as well as if performance in terms of Balanced Accuracy has degraded from the
# reference to evaluation set. The key detail displays whether the given performance metric has degraded beyond a
# defined threshold.',
#             'matters': 'During production, factors like distribution shift or a change in <span>p(y|x)</span> may
# cause model performance to decrease significantly.',
#             'threshold': '0.6',
#             'category': 'performance',
#             'created_at': '2023-08-10T09:43:47.035829Z'
#         },
#         {
#             'uuid': '00000000-0000-0000-0000-000000000000',
#             'risk': 'Top K Accuracy Score',
#             'value': '1.00',
#             'severity': 'pass',
#             'summary': 'top_k_accuracy_score has a value of 1.0 with pass as Severity Index against the 1 as
# threshold ',
#             'description': 'This test checks the Top-K Accuracy metric to see both if its performance on the
# evaluation set alone is satisfactory, as well as if performance in terms of Top-K Accuracy has degraded from the
# reference to evaluation set. The key detail displays whether the given performance metric has degraded beyond a
# defined threshold.',
#             'matters': 'During production, factors like distribution shift or a change in <span>p(y|x)</span> may
# cause model performance to decrease significantly.',
#             'threshold': '1',
#             'category': 'performance',
#             'created_at': '2023-08-10T09:43:55.672595Z'
#         },
#         {
#             'uuid': '00000000-0000-0000-0000-000000000000',
#             'risk': 'Log Loss',
#             'value': '7.79',
#             'severity': 'low',
#             'summary': 'log_loss has a value of 7.79 with low as Severity Index against the 0.6 as threshold ',
#             'description': 'This test checks the Log Loss metric to see both if its performance on the evaluation
# set alone is satisfactory, as well as if performance in terms of Log Loss has degraded from the reference to
# evaluation set. The key detail displays whether the given performance metric has degraded beyond a defined
# threshold.',
#             'matters': 'During production, factors like distribution shift or a change in <span>p(y|x)</span> may
# cause model performance to decrease significantly.',
#             'threshold': '0.6',
#             'category': 'performance',
#             'created_at': '2023-08-10T09:43:56.596098Z'
#         },
#         {
#             'uuid': '00000000-0000-0000-0000-000000000000',
#             'risk': 'Average Precision Score',
#             'value': '0.45',
#             'severity': 'moderate',
#             'summary': 'average_precision_score has a value of 0.45 with moderate as Severity Index against the 0.6
# as threshold ',
#             'description': 'This test checks the Average Precision metric to see both if its performance on the
# evaluation set alone is satisfactory, as well as if performance in terms of Average Precision has degraded from the
# reference to evaluation set. The key detail displays whether the given performance metric has degraded beyond a
# defined threshold.',
#             'matters': 'During production, factors like distribution shift or a change in <span>p(y|x)</span> may
# cause model performance to decrease significantly.',
#             'threshold': '0.6',
#             'category': 'performance',
#             'created_at': '2023-08-10T09:43:57.521855Z'
#         },
#         {
#             'uuid': '00000000-0000-0000-0000-000000000000',
#             'risk': 'Precision',
#             'value': '0.51',
#             'severity': 'pass',
#             'summary': 'precision has a value of 0.51 with moderate as Severity Index against the 0.5 as threshold
# ',
#             'description': 'This test checks the Precision metric to see both if its performance on the evaluation
# set alone is satisfactory, as well as if performance in terms of Precision has degraded from the reference to
# evaluation set. The key detail displays whether the given performance metric has degraded beyond a defined
# threshold.',
#             'matters': 'During production, factors like distribution shift or a change in <span>p(y|x)</span> may
# cause model performance to decrease significantly.',
#             'threshold': '0.5',
#             'category': 'performance',
#             'created_at': '2023-08-10T09:43:44.204207Z'
#         },
#         {
#             'uuid': '00000000-0000-0000-0000-000000000000',
#             'risk': 'Balanced Accuracy',
#             'value': '0.79',
#             'severity': 'moderate',
#             'summary': 'balanced_accuracy has a value of 0.79 with moderate as Severity Index against the 0.8 as
# threshold',
#             'description': 'This test checks the Balanced Accuracy metric to see both if its performance on the
# evaluation set alone is satisfactory, as well as if performance in terms of Balanced Accuracy has degraded from the
# reference to evaluation set. The key detail displays whether the given performance metric has degraded beyond a
# defined threshold.',
#             'matters': 'During production, factors like distribution shift or a change in <span>p(y|x)</span> may
# cause model performance to decrease significantly.',
#             'threshold': '0.8',
#             'category': 'fairness',
#             'created_at': '2023-08-10T09:44:00.486079Z'
#         },
#         {
#             'uuid': '00000000-0000-0000-0000-000000000000',
#             'risk': 'Balanced Acc Error',
#             'value': '0.01',
#             'severity': 'pass',
#             'summary': 'balanced_acc_error has a value of 0.01 with pass as Severity Index against the 0.009 as
# threshold',
#             'description': 'This test checks the Balanced Accuracy Error metric to see both if its performance on
# the evaluation set alone is satisfactory, as well as if performance in terms of Balanced Accuracy Error has
# degraded from the reference to evaluation set. The key detail displays whether the given performance metric has
# degraded beyond a defined threshold.',
#             'matters': 'During production, factors like distribution shift or a change in <span>p(y|x)</span> may
# cause model performance to decrease significantly.',
#             'threshold': '0.009',
#             'category': 'fairness',
#             'created_at': '2023-08-10T09:44:02.21859Z'
#         },
#         {
#             'uuid': '00000000-0000-0000-0000-000000000000',
#             'risk': 'Selection Rate',
#             'value': '0.35',
#             'severity': 'pass',
#             'summary': 'selection_rate has a value of 0.35 with pass as Severity Index against the 0.34 as
# threshold',
#             'description': 'This test checks the Selection Rate metric to see both if its performance on the
# evaluation set alone is satisfactory, as well as if performance in terms of Selection Rate has degraded from the
# reference to evaluation set. The key detail displays whether the given performance metric has degraded beyond a
# defined threshold.',
#             'matters': 'During production, factors like distribution shift or a change in <span>p(y|x)</span> may
# cause model performance to decrease significantly.',
#             'threshold': '0.34',
#             'category': 'fairness',
#             'created_at': '2023-08-10T09:44:03.251141Z'
#         },
#         {
#             'uuid': '00000000-0000-0000-0000-000000000000',
#             'risk': 'False Positive Rate',
#             'value': '0.22',
#             'severity': 'pass',
#             'summary': 'false_positive_rate has a value of 0.22 with pass as Severity Index against the 0.2 as
# threshold',
#             'description': 'This test checks the False Positive Rate metric to see both if its performance on the
# evaluation set alone is satisfactory, as well as if performance in terms of False Positive Rate has degraded from
# the reference to evaluation set. The key detail displays whether the given performance metric has degraded beyond a
# defined threshold.',
#             'matters': 'During production, factors like distribution shift or a change in <span>p(y|x)</span> may
# cause model performance to decrease significantly.',
#             'threshold': '0.2',
#             'category': 'fairness',
#             'created_at': '2023-08-10T09:44:04.171281Z'
#         },
#         {
#             'uuid': '00000000-0000-0000-0000-000000000000',
#             'risk': 'False Positive Error',
#             'value': '0.01',
#             'severity': 'pass',
#             'summary': 'false_positive_error has a value of 0.01 with low as Severity Index against the 0.008 as
# threshold',
#             'description': 'This test checks the False Positive Error metric to see both if its performance on the
# evaluation set alone is satisfactory, as well as if performance in terms of False Positive Error has degraded from
# the reference to evaluation set. The key detail displays whether the given performance metric has degraded beyond a
# defined threshold.',
#             'matters': 'During production, factors like distribution shift or a change in <span>p(y|x)</span> may
# cause model performance to decrease significantly.',
#             'threshold': '0.008',
#             'category': 'fairness',
#             'created_at': '2023-08-10T09:44:05.403809Z'
#         },
#         {
#             'uuid': '00000000-0000-0000-0000-000000000000',
#             'risk': 'False Negative Rate',
#             'value': '0.20',
#             'severity': 'pass',
#             'summary': 'false_negative_rate has a value of 0.2 with pass as Severity Index against the 0.18 as
# threshold',
#             'description': 'This test checks the False Negative Rate metric to see both if its performance on the
# evaluation set alone is satisfactory, as well as if performance in terms of False Negative Rate has degraded from
# the reference to evaluation set. The key detail displays whether the given performance metric has degraded beyond a
# defined threshold.',
#             'matters': 'During production, factors like distribution shift or a change in <span>p(y|x)</span> may
# cause model performance to decrease significantly.',
#             'threshold': '0.18',
#             'category': 'fairness',
#             'created_at': '2023-08-10T09:44:06.285548Z'
#         },
#         {
#             'uuid': '00000000-0000-0000-0000-000000000000',
#             'risk': 'False Negative Error',
#             'value': '0.02',
#             'severity': 'pass',
#             'summary': 'false_negative_error has a value of 0.02 with pass as Severity Index against the 0.015 as
# threshold',
#             'description': 'This test checks the False Negative Error metric to see both if its performance on the
# evaluation set alone is satisfactory, as well as if performance in terms of False Negative Error has degraded from
# the reference to evaluation set. The key detail displays whether the given performance metric has degraded beyond a
# defined threshold.',
#             'matters': 'During production, factors like distribution shift or a change in <span>p(y|x)</span> may
# cause model performance to decrease significantly.',
#             'threshold': '0.015',
#             'category': 'fairness',
#             'created_at': '2023-08-10T09:44:07.351224Z'
#         },
#         {
#             'uuid': '00000000-0000-0000-0000-000000000000',
#             'risk': 'True Positive Rate',
#             'value': '0.80',
#             'severity': 'pass',
#             'summary': 'true_positive_rate has a value of 0.8 with moderate as Severity Index against the 0.8 as
# threshold',
#             'description': 'This test checks the True Positive Rate metric to see both if its performance on the
# evaluation set alone is satisfactory, as well as if performance in terms of True Positive Rate has degraded from
# the reference to evaluation set. The key detail displays whether the given performance metric has degraded beyond a
# defined threshold.',
#             'matters': 'During production, factors like distribution shift or a change in <span>p(y|x)</span> may
# cause model performance to decrease significantly.',
#             'threshold': '0.8',
#             'category': 'fairness',
#             'created_at': '2023-08-10T09:44:09.093522Z'
#         },
#         {
#             'uuid': '00000000-0000-0000-0000-000000000000',
#             'risk': 'True Negative Rate',
#             'value': '0.78',
#             'severity': 'moderate',
#             'summary': 'true_negative_rate has a value of 0.78 with moderate as Severity Index against the 0.79 as
# threshold',
#             'description': 'This test checks the True Negative Rate metric to see both if its performance on the
# evaluation set alone is satisfactory, as well as if performance in terms of True Negative Rate has degraded from
# the reference to evaluation set. The key detail displays whether the given performance metric has degraded beyond a
# defined threshold.',
#             'matters': 'During production, factors like distribution shift or a change in <span>p(y|x)</span> may
# cause model performance to decrease significantly.',
#             'threshold': '0.79',
#             'category': 'fairness',
#             'created_at': '2023-08-10T09:44:10.213056Z'
#         },
#         {
#             'uuid': '00000000-0000-0000-0000-000000000000',
#             'risk': 'Brier Score Loss',
#             'value': '0.22',
#             'severity': 'high',
#             'summary': 'brier_score_loss has a value of 0.22 with high as Severity Index against the 0.6 as
# threshold ',
#             'description': 'This test checks the Brier Score Loss metric to see both if its performance on the
# evaluation set alone is satisfactory, as well as if performance in terms of Brier Score Loss has degraded from the
# reference to evaluation set. The key detail displays whether the given performance metric has degraded beyond a
# defined threshold.',
#             'matters': 'During production, factors like distribution shift or a change in <span>p(y|x)</span> may
# cause model performance to decrease significantly.',
#             'threshold': '0.6',
#             'category': 'performance',
#             'created_at': '2023-08-10T09:43:59.427638Z'
#         },
#         {
#             'uuid': '00000000-0000-0000-0000-000000000000',
#             'risk': 'Equalized Odds Difference',
#             'value': '0.13',
#             'severity': 'pass',
#             'summary': 'equalized_odds_difference has a value of 0.13 with high as Severity Index against the 0.12
# as threshold',
#             'description': 'This test checks the Equalized Odds Difference metric to see both if its performance on
# the evaluation set alone is satisfactory, as well as if performance in terms of Equalized Odds Difference has
# degraded from the reference to evaluation set. The key detail displays whether the given performance metric has
# degraded beyond a defined threshold.',
#             'matters': 'During production, factors like distribution shift or a change in <span>p(y|x)</span> may
# cause model performance to decrease significantly.',
#             'threshold': '0.12',
#             'category': 'fairness',
#             'created_at': '2023-08-10T09:44:14.310749Z'
#         },
#         {
#             'uuid': '00000000-0000-0000-0000-000000000000',
#             'risk': 'Equalized Odds Ratio',
#             'value': '0.53',
#             'severity': 'pass',
#             'summary': 'equalized_odds_ratio has a value of 0.53 with low as Severity Index against the 0.5 as
# threshold',
#             'description': 'This test checks for equal true positive and false positive rates over all subsets for
# each protected feature. The test first splits the dataset into various subset classes within the feature column. If
# the feature is categorical, the data is split based on the feature values. We then test whether the true positive
# and false positive rates of that subset significantly vary compared to the largest subset.',
#             'matters': 'Equalized odds (or disparate mistreatment) is an important measure of fairness in machine
# learning. Subjects in protected groups may have different true positive rates or false positive rates, which imply
# that the model may be biased on those protected features. Fulfilling the condition of equalized odds may be a
# requirement in various legal/compliance settings.',
#             'threshold': '0.5',
#             'category': 'fairness',
#             'created_at': '2023-08-10T09:44:15.302992Z'
#         },
#         {
#             'uuid': '00000000-0000-0000-0000-000000000000',
#             'risk': 'Accuracy',
#             'value': '0.78',
#             'severity': 'moderate',
#             'summary': 'accuracy has a value of 0.78 with moderate as Severity Index against the 0.8 as threshold
# ',
#             'description': 'This test checks the Accuracy metric to see both if its performance on the evaluation
# set alone is satisfactory, as well as if performance in terms of Accuracy has degraded from the reference to
# evaluation set. The key detail displays whether the given performance metric has degraded beyond a defined
# threshold.',
#             'matters': 'During production, factors like distribution shift or a change in <span>p(y|x)</span> may
# cause model performance to decrease significantly.',
#             'threshold': '0.8',
#             'category': 'performance',
#             'created_at': '2023-08-10T09:43:43.283361Z'
#         },
#         {
#             'uuid': '00000000-0000-0000-0000-000000000000',
#             'risk': 'Roc Auc',
#             'value': '0.79',
#             'severity': 'pass',
#             'summary': 'roc_auc has a value of 0.79 with pass as Severity Index against the 0.6 as threshold ',
#             'description': 'This test checks the ROC AUC metric to see both if its performance on the evaluation
# set alone is satisfactory, as well as if performance in terms of ROC AUC has degraded from the reference to
# evaluation set. The key detail displays whether the given performance metric has degraded beyond a defined
# threshold.',
#             'matters': 'During production, factors like distribution shift or a change in <span>p(y|x)</span> may
# cause model performance to decrease significantly.',
#             'threshold': '0.6',
#             'category': 'performance',
#             'created_at': '2023-08-10T09:43:58.436137Z'
#         },
#         {
#             'uuid': '00000000-0000-0000-0000-000000000000',
#             'risk': 'Demographic Parity Difference',
#             'value': '0.07',
#             'severity': 'pass',
#             'summary': 'demographic_parity_difference has a value of 0.07 with high as Severity Index against the
# 0.05 as threshold',
#             'description': 'This test checks the Demographic Parity Difference metric to see both if its
# performance on the evaluation set alone is satisfactory, as well as if performance in terms of Demographic Parity
# Difference has degraded from the reference to evaluation set. The key detail displays whether the given performance
# metric has degraded beyond a defined threshold.',
#             'matters': 'During production, factors like distribution shift or a change in <span>p(y|x)</span> may
# cause model performance to decrease significantly.',
#             'threshold': '0.05',
#             'category': 'fairness',
#             'created_at': '2023-08-10T09:44:12.431111Z'
#         },
#         {
#             'uuid': '00000000-0000-0000-0000-000000000000',
#             'risk': 'Demographic Parity Ratio',
#             'value': '0.82',
#             'severity': 'pass',
#             'summary': 'demographic_parity_ratio has a value of 0.82 with pass as Severity Index against the 0.8 as
# threshold',
#             'description': 'This test checks the Demographic Parity Ratio metric to see both if its performance on
# the evaluation set alone is satisfactory, as well as if performance in terms of Demographic Parity Ratio has
# degraded from the reference to evaluation set. The key detail displays whether the given performance metric has
# degraded beyond a defined threshold.',
#             'matters': 'During production, factors like distribution shift or a change in <span>p(y|x)</span> may
# cause model performance to decrease significantly.',
#             'threshold': '0.8',
#             'category': 'fairness',
#             'created_at': '2023-08-10T09:44:13.294187Z'
#         }
#     ],
#     'message': 'Risk for model version'
# }
#  Succesfully sent the evaluation results to PureML server
# {'complete': {'performance': {'accuracy': {'value': 0.7839047619047619,
#     'severity': 'moderate',
#     'threshold': 0.8,
#     'summary': 'accuracy has a value of 0.78 with moderate as Severity Index against the 0.8 as threshold ',
#     'description': 'This test checks the Accuracy metric to see both if its performance on the evaluation set alone is satisfactory, as well as if performance in terms of Accuracy has degraded from the reference to evaluation set. The key detail displays whether the given performance metric has degraded beyond a defined threshold.',
#     'matters': 'During production, factors like distribution shift or a change in <span>p(y|x)</span> may cause model performance to decrease significantly.'},
#    'precision': {'value': 0.5073369565217392,
#     'severity': 'pass',
#     'threshold': 0.5,
#     'summary': 'precision has a value of 0.51 with moderate as Severity Index against the 0.5 as threshold ',
#     'description': 'This test checks the Precision metric to see both if its performance on the evaluation set alone is satisfactory, as well as if performance in terms of Precision has degraded from the reference to evaluation set. The key detail displays whether the given performance metric has degraded beyond a defined threshold.',
#     'matters': 'During production, factors like distribution shift or a change in <span>p(y|x)</span> may cause model performance to decrease significantly.'},
#    'recall': {'value': 0.8037021093413689,
#     'severity': 'pass',
#     'threshold': 0.8,
#     'summary': 'recall has a value of 0.8 with moderate as Severity Index against the 0.8 as threshold ',
#     'description': 'This test checks the Recall metric to see both if its performance on the evaluation set alone is satisfactory, as well as if performance in terms of Recall has degraded from the reference to evaluation set. The key detail displays whether the given performance metric has degraded beyond a defined threshold.',
#     'matters': 'During production, factors like distribution shift or a change in <span>p(y|x)</span> may cause model performance to decrease significantly.'},
#    'f1': {'value': 0.6220223221722473,
#     'severity': 'pass',
#     'threshold': 0.6,
#     'summary': 'f1 has a value of 0.62 with moderate as Severity Index against the 0.6 as threshold ',
#     'description': 'This test checks the F1 metric to see both if its performance on the evaluation set alone is satisfactory, as well as if performance in terms of F1 has degraded from the reference to evaluation set. The key detail displays whether the given performance metric has degraded beyond a defined threshold.',
#     'matters': 'During production, factors like distribution shift or a change in <span>p(y|x)</span> may cause model performance to decrease significantly.'},
#    'balanced_accuracy_score': {'value': 0.7909913261638971,
#     'severity': 'pass',
#     'threshold': 0.6,
#     'summary': 'balanced_accuracy_score has a value of 0.79 with pass as Severity Index against the 0.6 as threshold ',
#     'description': 'This test checks the Balanced Accuracy metric to see both if its performance on the evaluation set alone is satisfactory, as well as if performance in terms of Balanced Accuracy has degraded from the reference to evaluation set. The key detail displays whether the given performance metric has degraded beyond a defined threshold.',
#     'matters': 'During production, factors like distribution shift or a change in <span>p(y|x)</span> may cause model performance to decrease significantly.'},
#    'top_k_accuracy_score': {'value': 1.0,
#     'severity': 'pass',
#     'threshold': 1,
#     'summary': 'top_k_accuracy_score has a value of 1.0 with pass as Severity Index against the 1 as threshold ',
#     'description': 'This test checks the Top-K Accuracy metric to see both if its performance on the evaluation set alone is satisfactory, as well as if performance in terms of Top-K Accuracy has degraded from the reference to evaluation set. The key detail displays whether the given performance metric has degraded beyond a defined threshold.',
#     'matters': 'During production, factors like distribution shift or a change in <span>p(y|x)</span> may cause model performance to decrease significantly.'},
#    'log_loss': {'value': 7.7888618609435065,
#     'severity': 'low',
#     'threshold': 0.6,
#     'summary': 'log_loss has a value of 7.79 with low as Severity Index against the 0.6 as threshold ',
#     'description': 'This test checks the Log Loss metric to see both if its performance on the evaluation set alone is satisfactory, as well as if performance in terms of Log Loss has degraded from the reference to evaluation set. The key detail displays whether the given performance metric has degraded beyond a defined threshold.',
#     'matters': 'During production, factors like distribution shift or a change in <span>p(y|x)</span> may cause model performance to decrease significantly.'},
#    'average_precision_score': {'value': 0.45117635353192354,
#     'severity': 'moderate',
#     'threshold': 0.6,
#     'summary': 'average_precision_score has a value of 0.45 with moderate as Severity Index against the 0.6 as threshold ',
#     'description': 'This test checks the Average Precision metric to see both if its performance on the evaluation set alone is satisfactory, as well as if performance in terms of Average Precision has degraded from the reference to evaluation set. The key detail displays whether the given performance metric has degraded beyond a defined threshold.',
#     'matters': 'During production, factors like distribution shift or a change in <span>p(y|x)</span> may cause model performance to decrease significantly.'},
#    'roc_auc': {'value': 0.790991326163897,
#     'severity': 'pass',
#     'threshold': 0.6,
#     'summary': 'roc_auc has a value of 0.79 with pass as Severity Index against the 0.6 as threshold ',
#     'description': 'This test checks the ROC AUC metric to see both if its performance on the evaluation set alone is satisfactory, as well as if performance in terms of ROC AUC has degraded from the reference to evaluation set. The key detail displays whether the given performance metric has degraded beyond a defined threshold.',
#     'matters': 'During production, factors like distribution shift or a change in <span>p(y|x)</span> may cause model performance to decrease significantly.'},
#    'brier_score_loss': {'value': 0.2160952380952381,
#     'severity': 'high',
#     'threshold': 0.6,
#     'summary': 'brier_score_loss has a value of 0.22 with high as Severity Index against the 0.6 as threshold ',
#     'description': 'This test checks the Brier Score Loss metric to see both if its performance on the evaluation set alone is satisfactory, as well as if performance in terms of Brier Score Loss has degraded from the reference to evaluation set. The key detail displays whether the given performance metric has degraded beyond a defined threshold.',
#     'matters': 'During production, factors like distribution shift or a change in <span>p(y|x)</span> may cause model performance to decrease significantly.'}},
#   'fairness': {'balanced_accuracy': {'value': 0.7909913261638971,
#     'severity': 'moderate',
#     'threshold': 0.8,
#     'summary': 'balanced_accuracy has a value of 0.79 with moderate as Severity Index against the 0.8 as threshold',
#     'description': 'This test checks the Balanced Accuracy metric to see both if its performance on the evaluation set alone is satisfactory, as well as if performance in terms of Balanced Accuracy has degraded from the reference to evaluation set. The key detail displays whether the given performance metric has degraded beyond a defined threshold.',
#     'matters': 'During production, factors like distribution shift or a change in <span>p(y|x)</span> may cause model performance to decrease significantly.'},
#    'balanced_acc_error': {'value': 0.009246206981808714,
#     'severity': 'pass',
#     'threshold': 0.009,
#     'summary': 'balanced_acc_error has a value of 0.01 with pass as Severity Index against the 0.009 as threshold',
#     'description': 'This test checks the Balanced Accuracy Error metric to see both if its performance on the evaluation set alone is satisfactory, as well as if performance in terms of Balanced Accuracy Error has degraded from the reference to evaluation set. The key detail displays whether the given performance metric has degraded beyond a defined threshold.',
#     'matters': 'During production, factors like distribution shift or a change in <span>p(y|x)</span> may cause model performance to decrease significantly.'},
#    'selection_rate': {'value': 0.3504761904761905,
#     'severity': 'pass',
#     'threshold': 0.34,
#     'summary': 'selection_rate has a value of 0.35 with pass as Severity Index against the 0.34 as threshold',
#     'description': 'This test checks the Selection Rate metric to see both if its performance on the evaluation set alone is satisfactory, as well as if performance in terms of Selection Rate has degraded from the reference to evaluation set. The key detail displays whether the given performance metric has degraded beyond a defined threshold.',
#     'matters': 'During production, factors like distribution shift or a change in <span>p(y|x)</span> may cause model performance to decrease significantly.'},
#    'false_positive_rate': {'value': 0.22171945701357465,
#     'severity': 'pass',
#     'threshold': 0.2,
#     'summary': 'false_positive_rate has a value of 0.22 with pass as Severity Index against the 0.2 as threshold',
#     'description': 'This test checks the False Positive Rate metric to see both if its performance on the evaluation set alone is satisfactory, as well as if performance in terms of False Positive Rate has degraded from the reference to evaluation set. The key detail displays whether the given performance metric has degraded beyond a defined threshold.',
#     'matters': 'During production, factors like distribution shift or a change in <span>p(y|x)</span> may cause model performance to decrease significantly.'},
#    'false_positive_error': {'value': 0.009003866814207595,
#     'severity': 'pass',
#     'threshold': 0.008,
#     'summary': 'false_positive_error has a value of 0.01 with low as Severity Index against the 0.008 as threshold',
#     'description': 'This test checks the False Positive Error metric to see both if its performance on the evaluation set alone is satisfactory, as well as if performance in terms of False Positive Error has degraded from the reference to evaluation set. The key detail displays whether the given performance metric has degraded beyond a defined threshold.',
#     'matters': 'During production, factors like distribution shift or a change in <span>p(y|x)</span> may cause model performance to decrease significantly.'},
#    'false_negative_rate': {'value': 0.19629789065863107,
#     'severity': 'pass',
#     'threshold': 0.18,
#     'summary': 'false_negative_rate has a value of 0.2 with pass as Severity Index against the 0.18 as threshold',
#     'description': 'This test checks the False Negative Rate metric to see both if its performance on the evaluation set alone is satisfactory, as well as if performance in terms of False Negative Rate has degraded from the reference to evaluation set. The key detail displays whether the given performance metric has degraded beyond a defined threshold.',
#     'matters': 'During production, factors like distribution shift or a change in <span>p(y|x)</span> may cause model performance to decrease significantly.'},
#    'false_negative_error': {'value': 0.016152391667917296,
#     'severity': 'pass',
#     'threshold': 0.015,
#     'summary': 'false_negative_error has a value of 0.02 with pass as Severity Index against the 0.015 as threshold',
#     'description': 'This test checks the False Negative Error metric to see both if its performance on the evaluation set alone is satisfactory, as well as if performance in terms of False Negative Error has degraded from the reference to evaluation set. The key detail displays whether the given performance metric has degraded beyond a defined threshold.',
#     'matters': 'During production, factors like distribution shift or a change in <span>p(y|x)</span> may cause model performance to decrease significantly.'},
#    'true_positive_rate': {'value': 0.8037021093413689,
#     'severity': 'pass',
#     'threshold': 0.8,
#     'summary': 'true_positive_rate has a value of 0.8 with moderate as Severity Index against the 0.8 as threshold',
#     'description': 'This test checks the True Positive Rate metric to see both if its performance on the evaluation set alone is satisfactory, as well as if performance in terms of True Positive Rate has degraded from the reference to evaluation set. The key detail displays whether the given performance metric has degraded beyond a defined threshold.',
#     'matters': 'During production, factors like distribution shift or a change in <span>p(y|x)</span> may cause model performance to decrease significantly.'},
#    'true_negative_rate': {'value': 0.7782805429864253,
#     'severity': 'moderate',
#     'threshold': 0.79,
#     'summary': 'true_negative_rate has a value of 0.78 with moderate as Severity Index against the 0.79 as threshold',
#     'description': 'This test checks the True Negative Rate metric to see both if its performance on the evaluation set alone is satisfactory, as well as if performance in terms of True Negative Rate has degraded from the reference to evaluation set. The key detail displays whether the given performance metric has degraded beyond a defined threshold.',
#     'matters': 'During production, factors like distribution shift or a change in <span>p(y|x)</span> may cause model performance to decrease significantly.'},
#    'demographic_parity_difference': {'value': 0.06686397746375322,
#     'severity': 'pass',
#     'threshold': 0.05,
#     'summary': 'demographic_parity_difference has a value of 0.07 with high as Severity Index against the 0.05 as threshold',
#     'description': 'This test checks the Demographic Parity Difference metric to see both if its performance on the evaluation set alone is satisfactory, as well as if performance in terms of Demographic Parity Difference has degraded from the reference to evaluation set. The key detail displays whether the given performance metric has degraded beyond a defined threshold.',
#     'matters': 'During production, factors like distribution shift or a change in <span>p(y|x)</span> may cause model performance to decrease significantly.'},
#    'demographic_parity_ratio': {'value': 0.8225995014971295,
#     'severity': 'pass',
#     'threshold': 0.8,
#     'summary': 'demographic_parity_ratio has a value of 0.82 with pass as Severity Index against the 0.8 as threshold',
#     'description': 'This test checks the Demographic Parity Ratio metric to see both if its performance on the evaluation set alone is satisfactory, as well as if performance in terms of Demographic Parity Ratio has degraded from the reference to evaluation set. The key detail displays whether the given performance metric has degraded beyond a defined threshold.',
#     'matters': 'During production, factors like distribution shift or a change in <span>p(y|x)</span> may cause model performance to decrease significantly.'},
#    'equalized_odds_difference': {'value': 0.1263408722425116,
#     'severity': 'pass',
#     'threshold': 0.12,
#     'summary': 'equalized_odds_difference has a value of 0.13 with high as Severity Index against the 0.12 as threshold',
#     'description': 'This test checks the Equalized Odds Difference metric to see both if its performance on the evaluation set alone is satisfactory, as well as if performance in terms of Equalized Odds Difference has degraded from the reference to evaluation set. The key detail displays whether the given performance metric has degraded beyond a defined threshold.',
#     'matters': 'During production, factors like distribution shift or a change in <span>p(y|x)</span> may cause model performance to decrease significantly.'},
#    'equalized_odds_ratio': {'value': 0.5333313169197266,
#     'severity': 'pass',
#     'threshold': 0.5,
#     'summary': 'equalized_odds_ratio has a value of 0.53 with low as Severity Index against the 0.5 as threshold',
#     'description': 'This test checks for equal true positive and false positive rates over all subsets for each protected feature. The test first splits the dataset into various subset classes within the feature column. If the feature is categorical, the data is split based on the feature values. We then test whether the true positive and false positive rates of that subset significantly vary compared to the largest subset.',
#     'matters': 'Equalized odds (or disparate mistreatment) is an important measure of fairness in machine learning. Subjects in protected groups may have different true positive rates or false positive rates, which imply that the model may be biased on those protected features. Fulfilling the condition of equalized odds may be a requirement in various legal/compliance settings.'}}},
#  'subsets': {1: {'performance': {'accuracy': {'value': 0.8535292700554084,
#      'severity': 'pass'},
#     'precision': {'value': 0.6441336441336442, 'severity': 'pass'},
#     'recall': {'value': 0.8467824310520939, 'severity': 'pass'},
#     'f1': {'value': 0.7316857899382172, 'severity': 'pass'},
#     'balanced_accuracy_score': {'value': 0.8511970162826674,
#      'severity': 'pass'},
#     'top_k_accuracy_score': {'value': 1.0, 'severity': 'pass'},
#     'log_loss': {'value': 5.279340221773844, 'severity': 'low'},
#     'average_precision_score': {'value': 0.5815769239764197,
#      'severity': 'moderate'},
#     'roc_auc': {'value': 0.8511970162826674, 'severity': 'pass'},
#     'brier_score_loss': {'value': 0.14647072994459168, 'severity': 'high'}},
#    'fairness': {'balanced_accuracy': {'value': 0.8511970162826674,
#      'severity': 'pass'},
#     'balanced_acc_error': {'value': 0.012832841958631512, 'severity': 'pass'},
#     'selection_rate': {'value': 0.3100457721031077, 'severity': 'moderate'},
#     'false_positive_rate': {'value': 0.14438839848675913,
#      'severity': 'moderate'},
#     'false_positive_error': {'value': 0.012231901186880527, 'severity': 'low'},
#     'false_negative_rate': {'value': 0.15321756894790603,
#      'severity': 'moderate'},
#     'false_negative_error': {'value': 0.02256342004872587, 'severity': 'low'},
#     'true_positive_rate': {'value': 0.8467824310520939, 'severity': 'pass'},
#     'true_negative_rate': {'value': 0.8556116015132409, 'severity': 'pass'},
#     'demographic_parity_difference': {'value': 0.0, 'severity': 'high'},
#     'demographic_parity_ratio': {'value': 1.0, 'severity': 'pass'},
#     'equalized_odds_difference': {'value': 0.0, 'severity': 'high'},
#     'equalized_odds_ratio': {'value': 1.0, 'severity': 'low'}}},
#   2: {'performance': {'accuracy': {'value': 0.7383839974799181,
#      'severity': 'moderate'},
#     'precision': {'value': 0.43376514834935226, 'severity': 'moderate'},
#     'recall': {'value': 0.7723214285714286, 'severity': 'moderate'},
#     'f1': {'value': 0.5555258228525556, 'severity': 'moderate'},
#     'balanced_accuracy_score': {'value': 0.7507960789210789,
#      'severity': 'pass'},
#     'top_k_accuracy_score': {'value': 1.0, 'severity': 'pass'},
#     'log_loss': {'value': 9.429596515880231, 'severity': 'low'},
#     'average_precision_score': {'value': 0.38320268542607705,
#      'severity': 'moderate'},
#     'roc_auc': {'value': 0.7507960789210789, 'severity': 'pass'},
#     'brier_score_loss': {'value': 0.2616160025200819, 'severity': 'high'}},
#    'fairness': {'balanced_accuracy': {'value': 0.7507960789210789,
#      'severity': 'moderate'},
#     'balanced_acc_error': {'value': 0.012788216944843042, 'severity': 'pass'},
#     'selection_rate': {'value': 0.3769097495668609, 'severity': 'pass'},
#     'false_positive_rate': {'value': 0.2707292707292707, 'severity': 'pass'},
#     'false_positive_error': {'value': 0.012310226067216755, 'severity': 'low'},
#     'false_negative_rate': {'value': 0.22767857142857142, 'severity': 'pass'},
#     'false_negative_error': {'value': 0.02241901658609271, 'severity': 'pass'},
#     'true_positive_rate': {'value': 0.7723214285714286,
#      'severity': 'moderate'},
#     'true_negative_rate': {'value': 0.7292707292707292,
#      'severity': 'moderate'},
#     'demographic_parity_difference': {'value': 0.0, 'severity': 'high'},
#     'demographic_parity_ratio': {'value': 1.0, 'severity': 'pass'},
#     'equalized_odds_difference': {'value': 0.0, 'severity': 'high'},
#     'equalized_odds_ratio': {'value': 1.0, 'severity': 'low'}}}}}

# %%
import pureml
pureml.__version__
